# %% [markdown]
# <b>Dataset 1 : https://finance.yahoo.com/
#
# <b>Dataset 2 : https://bit.ly/36fFPI6

# %%
#importing alll imp Libraries
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt  
# %matplotlib inline
import seaborn as sns

# %%
stock_df=pd.read_csv("BSESN.csv" )
stock_df.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2000-01-03  5209.540039  5384.660156  5209.540039  5375.109863
# 1  2000-01-04  5533.979980  5533.979980  5376.430176  5491.009766
# 2  2000-01-05  5265.089844  5464.350098  5184.479980  5357.000000
# 3  2000-01-06  5424.209961  5489.859863  5391.330078  5421.529785
# 4  2000-01-07  5358.279785  5463.250000  5330.580078  5414.479980
#
#      Adj Close  Volume
# 0  5375.109863     0.0
# 1  5491.009766     0.0
# 2  5357.000000     0.0
# 3  5421.529785     0.0
# 4  5414.479980     0.0

# %%
stock_df.tail()
# Out:
#             Date          Open          High           Low         Close  \
# 5121  2020-06-18  33371.519531  34276.011719  33371.519531  34208.050781
# 5122  2020-06-19  34335.378906  34848.371094  34136.390625  34731.730469
# 5123  2020-06-22  34892.031250  35213.519531  34794.398438  34911.320313
# 5124  2020-06-23  35015.730469  35482.160156  34843.691406  35430.429688
# 5125  2020-06-24  35679.738281  35706.550781  34794.929688  34868.980469
#
#          Adj Close   Volume
# 5121  34208.050781  21200.0
# 5122  34731.730469  27900.0
# 5123  34911.320313  25100.0
# 5124  35430.429688  25200.0
# 5125  34868.980469  26600.0

# %%
stock_df.shape
# Out:
# (5126, 7)

# %%
stock_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5126 entries, 0 to 5125
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5126 non-null   object
#  1   Open       5040 non-null   float64
#  2   High       5040 non-null   float64
#  3   Low        5040 non-null   float64
#  4   Close      5040 non-null   float64
#  5   Adj Close  5040 non-null   float64
#  6   Volume     5040 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 280.5+ KB

# %%
#Converting Date column to datetime datatype
stock_df['Date'] = pd.to_datetime(stock_df['Date'], format= '%Y-%m-%d')
stock_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5126 entries, 0 to 5125
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       5126 non-null   datetime64[ns]
#  1   Open       5040 non-null   float64
#  2   High       5040 non-null   float64
#  3   Low        5040 non-null   float64
#  4   Close      5040 non-null   float64
#  5   Adj Close  5040 non-null   float64
#  6   Volume     5040 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 280.5 KB

# %%
stock_df.nunique()
# Out:
# Date         5126
# Open         5026
# High         5034
# Low          5034
# Close        5034
# Adj Close    5034
# Volume        456
# dtype: int64

# %%
stock_df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count   5040.000000   5040.000000   5040.000000   5040.000000   5040.000000
# mean   17356.533441  17463.069891  17215.749200  17336.138347  17336.138347
# std    10940.468051  10977.979736  10874.968330  10922.710318  10922.710318
# min     2621.889893   2682.590088   2594.870117   2600.120117   2600.120117
# 25%     6346.172363   6391.627441   6311.217407   6346.547363   6346.547363
# 50%    17043.790039  17141.790039  16887.560547  17022.089843  17022.089843
# 75%    26254.395508  26402.481933  26075.884278  26228.379395  26228.379395
# max    42263.000000  42273.871094  41850.289063  41952.628906  41952.628906
#
#              Volume
# count  5.040000e+03
# mean   7.789060e+04
# std    1.054362e+06
# min    0.000000e+00
# 25%    8.400000e+03
# 50%    1.310000e+04
# 75%    2.020000e+04
# max    3.181510e+07

# %%
#plotting the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(stock_df.corr(), annot = True, fmt = '.2f', cmap = 'viridis')
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 12)
# Out:
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5]),
#  <a list of 6 Text major ticklabel objects>)

# %% [markdown]
# <b> Checking the missing value

# %%
stock_df.isna().sum()
# Out:
# Date          0
# Open         86
# High         86
# Low          86
# Close        86
# Adj Close    86
# Volume       86
# dtype: int64

# %%
stock_df.dropna(inplace=True)

# %% [markdown]
# <b> Open Price History plot

# %%
plt.figure(figsize=(14, 7))
plt.plot(stock_df['Date'], stock_df['Open'])
plt.title("Open Price History", fontsize = 16)
plt.xlabel("Date", fontsize = 12)
plt.ylabel("Price", fontsize = 12)
plt.show()

# %% [markdown]
# <b> Close Price History plot

# %%
plt.figure(figsize=(14, 7))
plt.plot(stock_df['Date'], stock_df['Close'])
plt.title("Close Price History", fontsize = 16)
plt.xlabel("Date", fontsize = 12)
plt.ylabel("Price", fontsize = 12)
plt.show()

# %% [markdown]
# <b>Stock Price Growth History plot

# %%
plt.figure(figsize=(14, 7))
plt.plot(stock_df['Date'], stock_df['High'])
plt.title("Stock Price Groth History", fontsize = 16)
plt.xlabel("Date", fontsize = 12)
plt.ylabel("Price", fontsize = 12)
plt.show()

# %% [markdown]
# <b>Stock Price Growth History plot

# %%
plt.figure(figsize=(14, 8))
plt.plot(stock_df['Date'], stock_df['Low'])
plt.title("Stock Price Lower History", fontsize = 16)
plt.xlabel("Date", fontsize = 14)
plt.ylabel("Price", fontsize = 14)
plt.show()

# %% [markdown]
# <b>Stock Price Adj Close and Close Price plot

# %%
plt.figure(figsize=(14, 8))
plt.plot(stock_df['Date'], stock_df['Adj Close'])
plt.title("Stock Price Adj Close and Close Price", fontsize = 16)
plt.xlabel("Date", fontsize = 14)
plt.ylabel("Price", fontsize = 14)
plt.show()

# %% [markdown]
# <b> Stock Price Volume plot

# %%
plt.figure(figsize=(14, 8))
plt.plot(stock_df['Date'], stock_df['Volume'])
plt.title("Stock Price Adj Close and Close Price", fontsize = 16)
plt.xlabel("Date", fontsize = 14)
plt.ylabel("Price", fontsize = 14)
plt.show()

# %% [markdown]
# <b>  Stock market volume price Prediction

# %%
##stock_df['Date'] = pd.to_datetime(stock_df['Date'], format= '%Y%m%d')
#stock_df.info()

# %%
stock_df.dtypes
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume              float64
# dtype: object

# %%
#locking the datastet ( here we are eliminating the date column as it is timestamp)
x=stock_df.iloc[:,1:7].values
x
# Out:
# array([[ 5209.540039,  5384.660156,  5209.540039,  5375.109863,
#          5375.109863,     0.      ],
#        [ 5533.97998 ,  5533.97998 ,  5376.430176,  5491.009766,
#          5491.009766,     0.      ],
#        [ 5265.089844,  5464.350098,  5184.47998 ,  5357.      ,
#          5357.      ,     0.      ],
#        ...,
#        [34892.03125 , 35213.519531, 34794.398438, 34911.320313,
#         34911.320313, 25100.      ],
#        [35015.730469, 35482.160156, 34843.691406, 35430.429688,
#         35430.429688, 25200.      ],
#        [35679.738281, 35706.550781, 34794.929688, 34868.980469,
#         34868.980469, 26600.      ]])

# %%
y=stock_df.iloc[:,-1:].values
y
# Out:
# array([[    0.],
#        [    0.],
#        [    0.],
#        ...,
#        [25100.],
#        [25200.],
#        [26600.]])

# %%
#Importing train test split fom sklearn
from sklearn.model_selection import train_test_split
xtrain ,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.20,random_state=0)

# %% [markdown]
# <b> Normalizing or Scaling the data

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
Xtrain = sc.fit_transform(xtrain)
Xtest = sc.fit_transform(xtest)

# %% [markdown]
# <b> Using Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor
r_reg= RandomForestRegressor(n_estimators=10, random_state=0)
r_reg.fit(Xtrain,ytrain)
# Out:
# <ipython-input-24-1fffb0a6aa4f>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   r_reg.fit(Xtrain,ytrain)
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
ypred=r_reg.predict(Xtest)
ypred
# Out:
# array([11900., 13900.,     0., ..., 46700.,     0.,  5420.])

# %%
#visualizing the result
df1 = pd.DataFrame()
df1
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df1['predict'] = ypred
df1['predict']
# Out:
# 0       11900.0
# 1       13900.0
# 2           0.0
# 3           0.0
# 4       14600.0
#          ...
# 1003    30930.0
# 1004    30200.0
# 1005    46700.0
# 1006        0.0
# 1007     5420.0
# Name: predict, Length: 1008, dtype: float64

# %%
plt.figure(figsize=(14, 8))
plt.plot(df1['predict'])
plt.title("Stock Price Volume Test Result", fontsize = 16)
plt.ylabel("Price", fontsize = 14)
plt.show()

# %% [markdown]
# <b>Accuracy of the model

# %%
print("Accuracy score : ", np.mean(ypred==ytest))
# Out:
# Accuracy score :  0.034618882275132275

# %% [markdown]
# <b>Textual Analysis

# %%
# Importing the dataset
news_df=pd.read_csv('india-news-headlines.csv')
news_df.head(5)
# Out:
#    publish_date headline_category  \
# 0      20010102           unknown
# 1      20010102           unknown
# 2      20010102           unknown
# 3      20010102           unknown
# 4      20010102           unknown
#
#                                        headline_text
# 0  Status quo will not be disturbed at Ayodhya; s...
# 1                Fissures in Hurriyat over Pak visit
# 2              America's unwanted heading for India?
# 3                 For bigwigs; it is destination Goa
# 4               Extra buses to clear tourist traffic

# %%
news_df.shape
# Out:
# (3424067, 3)

# %%
news_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3424067 entries, 0 to 3424066
# Data columns (total 3 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   publish_date       int64
#  1   headline_category  object
#  2   headline_text      object
# dtypes: int64(1), object(2)
# memory usage: 78.4+ MB

# %%
news_df.dtypes
# Out:
# publish_date          int64
# headline_category    object
# headline_text        object
# dtype: object

# %%
news_df['headline_text']
# Out:
# 0          Status quo will not be disturbed at Ayodhya; s...
# 1                        Fissures in Hurriyat over Pak visit
# 2                      America's unwanted heading for India?
# 3                         For bigwigs; it is destination Goa
# 4                       Extra buses to clear tourist traffic
#                                  ...
# 3424062    Covid-19: Despite dip in cases; Rajasthan amon...
# 3424063    Covid-19: Despite dip in cases; Rajasthan amon...
# 3424064    Covid-19: Despite dip in cases; Rajasthan amon...
# 3424065    Govt extends deadline for use of FASTag till F...
# 3424066    Celebs plan to party safely and responsibly on...
# Name: headline_text, Length: 3424067, dtype: object

# %% [markdown]
# <b>Removing missing values

# %%
news_df.drop('headline_category', axis=1, inplace=True)
news_df['publish_date'] = pd.to_datetime(news_df['publish_date'], format='%Y%m%d')
news_df.head()
# Out:
#   publish_date                                      headline_text
# 0   2001-01-02  Status quo will not be disturbed at Ayodhya; s...
# 1   2001-01-02                Fissures in Hurriyat over Pak visit
# 2   2001-01-02              America's unwanted heading for India?
# 3   2001-01-02                 For bigwigs; it is destination Goa
# 4   2001-01-02               Extra buses to clear tourist traffic

# %%
news_df.rename(columns={'publish_date': 'Date'}, inplace = True)

# %% [markdown]
# <b>Removing the duplicate data

# %%
news_df = news_df.drop_duplicates()
news_df.reset_index(inplace=True, drop=True)
news_df.head()
# Out:
#         Date                                      headline_text
# 0 2001-01-02  Status quo will not be disturbed at Ayodhya; s...
# 1 2001-01-02                Fissures in Hurriyat over Pak visit
# 2 2001-01-02              America's unwanted heading for India?
# 3 2001-01-02                 For bigwigs; it is destination Goa
# 4 2001-01-02               Extra buses to clear tourist traffic

# %%
news_df = news_df[:3000]

# %% [markdown]
# <b> I am   using 3000 rows of data because of my device computation speed. So 3000 rows willl be  quickly computed.

# %%
from textblob import TextBlob

def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# %%
news_df['Subjectivity'] = news_df['headline_text'].apply(getSubjectivity)
news_df['Polarity'] = news_df['headline_text'].apply(getPolarity)
news_df.head()
# Out:
#         Date                                      headline_text  Subjectivity  \
# 0 2001-01-02  Status quo will not be disturbed at Ayodhya; s...      0.000000
# 1 2001-01-02                Fissures in Hurriyat over Pak visit      0.000000
# 2 2001-01-02              America's unwanted heading for India?      0.000000
# 3 2001-01-02                 For bigwigs; it is destination Goa      0.000000
# 4 2001-01-02               Extra buses to clear tourist traffic      0.241667
#
#    Polarity
# 0      0.00
# 1      0.00
# 2      0.00
# 3      0.00
# 4      0.05

# %%
 plt.figure(figsize = (12, 8))
news_df['Subjectivity'].hist()
plt.show()

# %%
plt.figure(figsize = (12, 8))
news_df['Polarity'].hist()
plt.show()

# %% [markdown]
# # Sentiment Intensity Analyzer

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer 

senti_ana = SentimentIntensityAnalyzer()

# %%
news_df['compound'] = [senti_ana.polarity_scores(i)['compound'] for i in news_df['headline_text']]
news_df['Negative'] = [senti_ana.polarity_scores(i)['neg'] for i in news_df['headline_text']]
news_df['Neutral'] = [senti_ana.polarity_scores(i)['neu'] for i in news_df['headline_text']]
news_df['Positive'] = [senti_ana.polarity_scores(i)['pos'] for i in news_df['headline_text']]

# %%
news_df.head()
# Out:
#         Date                                      headline_text  Subjectivity  \
# 0 2001-01-02  Status quo will not be disturbed at Ayodhya; s...      0.000000
# 1 2001-01-02                Fissures in Hurriyat over Pak visit      0.000000
# 2 2001-01-02              America's unwanted heading for India?      0.000000
# 3 2001-01-02                 For bigwigs; it is destination Goa      0.000000
# 4 2001-01-02               Extra buses to clear tourist traffic      0.241667
#
#    Polarity  compound  Negative  Neutral  Positive
# 0      0.00    0.2924     0.000    0.805     0.195
# 1      0.00    0.0000     0.000    1.000     0.000
# 2      0.00   -0.2263     0.322    0.678     0.000
# 3      0.00    0.0000     0.000    1.000     0.000
# 4      0.05    0.3818     0.000    0.658     0.342

# %% [markdown]
# <b>Conclusion
#
#
#
# using regressor model we can predict stock Volume price. The Accuracy of our prediction uing this model is 34 % Accurate.
#
# As per my analyes News headline data contain first month of 2001 Date but the stock data Date have secound month of 2020 so news headline not much useful for stock prediction.

# %% [markdown]
# <b>Thank you!!
